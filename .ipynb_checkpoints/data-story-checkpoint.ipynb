# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('marchand_goals.csv')

# %%
df.head()
# Out:
#    Rank     Date   Tm Unnamed: 3  Opp Unnamed: 5 Unnamed: 6         Scorer  \
# 0     1   4/2/19  BOS          @  CBJ          W        NaN  Brad Marchand
# 1     2  3/31/19  BOS          @  DET          L        NaN  Brad Marchand
# 2     3  3/25/19  BOS          @  TBL          L        NaN  Brad Marchand
# 3     4  3/25/19  BOS          @  TBL          L        NaN  Brad Marchand
# 4     5  3/23/19  BOS          @  FLA          W        NaN  Brad Marchand
#
#    Age  Cr. Goal #           Assist1           Assist2              Goalie  \
# 0   30         262               NaN               NaN    Sergei Bobrovsky
# 1   30         261  Patrice Bergeron     Brandon Carlo        Jimmy Howard
# 2   30         260    David Pastrnak  Patrice Bergeron  Andrei Vasilevskiy
# 3   30         259    David Pastrnak  Patrice Bergeron  Andrei Vasilevskiy
# 4   30         258  Patrice Bergeron               NaN    Sam Montembeault
#
#   Per.   Time Strength Other            Arena Name
# ...

# %%
# df = df.rename(columns={"Unnamed: 3":"Home"})
# df['Win'] = df['Win'].fillna(0)
# df['Win'].loc[df['Win']=='L'] = df['Win'].loc[df['Win']=='L'].replace({"L":0},inplace=True)
df.head(15)
# Out:
#     Rank     Date   Tm Unnamed: 3  Opp Unnamed: 5 Unnamed: 6         Scorer  \
# 0      1   4/2/19  BOS          @  CBJ          W        NaN  Brad Marchand
# 1      2  3/31/19  BOS          @  DET          L        NaN  Brad Marchand
# 2      3  3/25/19  BOS          @  TBL          L        NaN  Brad Marchand
# 3      4  3/25/19  BOS          @  TBL          L        NaN  Brad Marchand
# 4      5  3/23/19  BOS          @  FLA          W        NaN  Brad Marchand
# 5      6  3/16/19  BOS        NaN  CBJ          W         OT  Brad Marchand
# 6      7  3/12/19  BOS          @  CBJ          L        NaN  Brad Marchand
# 7      8  3/12/19  BOS          @  CBJ          L        NaN  Brad Marchand
# 8      9   3/9/19  BOS        NaN  OTT          W        NaN  Brad Marchand
# 9     10   3/2/19  BOS        NaN  NJD          W        NaN  Brad Marchand
# 10    11  2/28/19  BOS        NaN  TBL          W        NaN  Brad Marchand
# ...

# %%
# df['Date'] = pd.to_datetime(df['Date'])
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1, 1, 1)  
sns.lineplot(x=df['Date'],y=df['Cr. Goal #'])
plt.title('Regular Season Goals');

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1, 1, 1)  
sns.barplot(x=df['Per.'],y=df.index,ci=None);

# %%
df_playoff = pd.read_csv('marchand_goals_playoffs.csv')

# %%
sns.pairplot(df)
